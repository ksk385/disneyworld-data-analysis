# %%
import pandas as pd

# %%
df=pd.read_csv('activities.csv')

# %%
df.head(5)
# Out:
#                      Activity Name  Activity Type   Park ID  \
# 0       Meet Donald Duck in Mexico  Entertainment  80007838
# 1   Raglan Road Live Entertainment  Entertainment  80007798
# 2              Atlantic Dance Hall  Entertainment  80008259
# 3  Meet Moana at Character Landing  Entertainment  80007823
# 4                 Springs Overlook  Entertainment     10460
#
#                             Park Name  \
# 0                               EPCOT
# 1                                 NaN
# 2                  Disney's BoardWalk
# 3  Disney's Animal Kingdom Theme Park
# 4                      Disney Springs
#
#                                                                                                                                                                                                                                                                   Timings  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Activity Name        278 non-null    object
#  1   Activity Type        278 non-null    object
#  2   Park ID              278 non-null    int64
#  3   Park Name            270 non-null    object
#  4   Timings              209 non-null    object
#  5   Height Restrictions  179 non-null    object
#  6   URL                  277 non-null    object
#  7   Location Lat         270 non-null    float64
#  8   Location Lng         270 non-null    float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 19.7+ KB

# %%
df.columns
# Out:
# Index(['Activity Name', 'Activity Type', 'Park ID', 'Park Name', 'Timings',
#        'Height Restrictions', 'URL', 'Location Lat', 'Location Lng'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Activity Name           0
# Activity Type           0
# Park ID                 0
# Park Name               8
# Timings                69
# Height Restrictions    99
# URL                     1
# Location Lat            8
# Location Lng            8
# dtype: int64

# %%
df.loc[df['Park ID'] == 80007798, 'Park Name'] = 'Disney Springs'

# %%
df.head(10)
# Out:
#                                 Activity Name  Activity Type   Park ID  \
# 0                  Meet Donald Duck in Mexico  Entertainment  80007838
# 1              Raglan Road Live Entertainment  Entertainment  80007798
# 2                         Atlantic Dance Hall  Entertainment  80008259
# 3             Meet Moana at Character Landing  Entertainment  80007823
# 4                            Springs Overlook  Entertainment     10460
# 5                         Command Performance  Entertainment  80007838
# 6         Fireworks & Nighttime Entertainment  Entertainment  80007798
# 7           Mickey's Magical Friendship Faire  Entertainment  80007944
# 8  Meet Edna Mode at the Edna Mode Experience  Entertainment  80007998
# 9      Indiana Jones™ Epic Stunt Spectacular!  Entertainment  80007998
#
#                             Park Name  \
# 0                               EPCOT
# 1                      Disney Springs
# 2                  Disney's BoardWalk
# ...

# %%
df['Height Restrictions'].value_counts()
# Out:
# Height Restrictions
# any-height                     148
# 40-inches-102-cm-or-taller       9
# 48-inches-122-cm-or-taller       7
# 38-inches-97-cm-or-taller        4
# 44-inches-112-cm-or-taller       3
# 32-inches-81-cm-or-taller        3
# 48-inches-122-cm-or-shorter      2
# 42-inches-107-cm-or-taller       1
# 35-inches-89-cm-or-taller        1
# 60-inches-152-cm-or-shorter      1
# Name: count, dtype: int64

# %%
df.loc[df['Height Restrictions'].isna()]
# Out:
#                               Activity Name  Activity Type   Park ID  \
# 0                Meet Donald Duck in Mexico  Entertainment  80007838
# 1            Raglan Road Live Entertainment  Entertainment  80007798
# 2                       Atlantic Dance Hall  Entertainment  80008259
# 3           Meet Moana at Character Landing  Entertainment  80007823
# 4                          Springs Overlook  Entertainment     10460
# ..                                      ...            ...       ...
# 154  Star Wars™ at Walt Disney World Resort     Attraction  80007998
# 174     Pirates at Walt Disney World Resort     Attraction  80007944
# 193               Vultures - Disney Animals     Attraction  80007823
# 240                       Cinderella Castle     Attraction  80007944
# 257           Star Wars Photo Opportunities     Attraction  80007798
#
#                               Park Name  \
# 0                                 EPCOT
# 1                        Disney Springs
# ...

# %%
df.loc[df['Height Restrictions'] == 'any-height'] = 0
df['Height Restrictions'] = df['Height Restrictions'].apply(lambda x: int(x.split('-')[0]) if isinstance(x, str) and not x.startswith('any') else x)

# %%
df['Height Restrictions'].value_counts()
# Out:
# Height Restrictions
# 0.0     148
# 48.0      9
# 40.0      9
# 38.0      4
# 44.0      3
# 32.0      3
# 42.0      1
# 35.0      1
# 60.0      1
# Name: count, dtype: int64

# %%
# Set the display.max_colwidth option to None
pd.set_option('display.max_colwidth', None)

df['Height Restrictions'].isnull().sum()
df.loc[df['Height Restrictions'].isna() & (df['Park Name'] == 'Magic Kingdom Park'), ['Park Name', 'Activity Name', 'Activity Type', 'Height Restrictions', 'URL']]
# Out:
#               Park Name  \
# 7    Magic Kingdom Park
# 23   Magic Kingdom Park
# 27   Magic Kingdom Park
# 28   Magic Kingdom Park
# 33   Magic Kingdom Park
# 37   Magic Kingdom Park
# 42   Magic Kingdom Park
# 43   Magic Kingdom Park
# 45   Magic Kingdom Park
# 48   Magic Kingdom Park
# 56   Magic Kingdom Park
# 60   Magic Kingdom Park
# 69   Magic Kingdom Park
# 73   Magic Kingdom Park
# 82   Magic Kingdom Park
# 83   Magic Kingdom Park
# 86   Magic Kingdom Park
# 88   Magic Kingdom Park
# 151  Magic Kingdom Park
# 174  Magic Kingdom Park
# 240  Magic Kingdom Park
#
#                                                               Activity Name  \
# 7                                         Mickey's Magical Friendship Faire
# 23       Meet Cinderella and a Visiting Princess at Princess Fairytale Hall
# 27                                                      Let the Magic Begin
# 28                      Meet Winnie the Pooh and Tigger at The Thotful Spot
# ...

# %%
df.loc[(df['Height Restrictions'] <= 40) & (df['Park Name'].isin(['EPCOT', 'Magic Kingdom Park']))]
# Out:
#                                     Activity Name Activity Type   Park ID  \
# 150                 Big Thunder Mountain Railroad    Attraction  80007944
# 168                                    Test Track    Attraction  80007838
# 191                      Soarin' Around the World    Attraction  80007838
# 219                         Tomorrowland Speedway    Attraction  80007944
# 226                               The Barnstormer    Attraction  80007944
# 229                       Seven Dwarfs Mine Train    Attraction  80007944
# 254  Tiana's Bayou Adventure – Coming Summer 2024    Attraction  80007944
# 261                                Mission: SPACE    Attraction  80007838
#
#               Park Name                                     Timings  \
# 150  Magic Kingdom Park                        08:00:00 to 23:00:00
# 168               EPCOT  08:30:00 to 09:00:00, 09:00:00 to 21:00:00
# 191               EPCOT  08:30:00 to 09:00:00, 09:00:00 to 21:00:00
# ...
